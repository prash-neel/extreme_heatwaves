# %%
#use xarray package to create new netcdfs for pattern correlation
#compare 2021 heatwave to reanalysis data and find pattern corr
#Low res version - reduce resolution of reanalysis to allow like for like comparison to model data patter correlation

##IMPORT PACKAGES
from sewar.full_ref import mse, rmse, psnr, uqi, ssim, ergas, scc, rase, sam, msssim, vifp
import cartopy.feature as cfeature ## for lakes/borders etc
countries_50m = cfeature.NaturalEarthFeature('cultural','admin_0_countries','50m',edgecolor='k',facecolor='none')
import cartopy.crs as ccrs
import numpy as np
from netCDF4 import Dataset  
import xarray as xr
import datetime as dt
import pandas as pd

import matplotlib.pyplot as plt
import math
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import os
import iris
from iris.experimental.equalise_cubes import equalise_attributes
from iris.util import unify_time_units
import iris.coord_categorisation
import iris.plot as iplt
import iris.quickplot as qplt
import iris.analysis.stats
import pandas as pd
import seaborn as sns
import glob
import cf_units as unit

crs = ccrs.PlateCarree()

import warnings
warnings.filterwarnings("ignore")

def sorted(cube, coord):
    coord_to_sort = cube.coord(coord)
    assert coord_to_sort.ndim == 1, 'One dim coords only please.'
    dim, = cube.coord_dims(coord_to_sort)
    index = [slice(None)] * cube.ndim
    index[dim] = np.argsort(coord_to_sort.points)
    return cube[tuple(index)]

# %%
#Lat long boundaries
#Specify min and max values of latitude and longitude 
lat_min = 30
lat_max =70
lon_min = 215 #-145
lon_max = 290 #-70

fn = '/nfs/annie/ee21pnm/all_PNW_small.nc'
fn2 = '/nfs/annie/ee21pnm/210628_pcorr_small.nc' 
set_date = dt.date(2021,6,28)

output_name = "/nfs/see-fs-01_teaching/ee21pnm/Spreadsheets/PNW_Corr_June2021_lowRES.xlsx"

#save histograms
pathout ="/nfs/see-fs-01_teaching/ee21pnm/Project/output/Pattern_Corr_Histograms/PNW"

# %%
#LOWRES
#extract latitudes from climate model data
path = '/nfs/annie/earamay/Prash/historical/'
membername = 'r101i1p1f1'
model_year = 2000
model_day = 30
model_month = 7

zfile = glob.glob(path + "Z/zg_day_EC-Earth3_historical_" + membername + "_gr_" +str(model_year)+ "0101-" +str(model_year)+ "1231.nc")
fn_model = zfile[0]

model_day2 = dt.datetime(model_year, model_month, model_day,12)

cube_model = iris.load_cube(fn_model)

longitude_1 = cube_model.coord('longitude')
latitude_1 = cube_model.coord('latitude')
pressure_1 = cube_model.coord('air_pressure')


# Functions to identify latitudes and longitudes we want to subset to
def region_lat(input):
    return lat_min  <= input <= lat_max 

def region_long(input):
    return lon_min  <= input <= lon_max 

def pressure_500(input):
    return input == 50000

region_con = iris.Constraint(latitude = region_lat, longitude = region_long)
pressure_con = iris.Constraint( air_pressure= pressure_500)
date_con = iris.Constraint(time=lambda t: t.point == unit.date2num(model_day2, 'days since 1850-01-01 00:00:00','proleptic_gregorian'))


# Subset the cube to the location of interest
cube_model_subset = cube_model.extract(region_con & pressure_con & date_con)
#find spatial average for each day
coords_model = ('longitude', 'latitude')

longitude_lowRES = cube_model_subset.coord('longitude')
latitude_lowRES = cube_model_subset.coord('latitude')
pressure_lowRES = cube_model_subset.coord('air_pressure')

# %%
##Read in geopotential data

ncZ = Dataset("/nfs/annie/ee21pnm/daymean_present.nc","r")

#information on the file's variables
#print(ncZ.variables.keys())
#for var in ['time', 'realization', 'plev', 'lat', 'lon', 'geopotential']:
#    print(var,ncZ.variables[var])
    
    
lat = ncZ.variables['latitude'][:]  
lon = ncZ.variables['longitude'][:]
z = ncZ.variables['z'][:]
time = ncZ.variables['time'][:]

widths = np.linspace(0, 2, lat.size)

# Convert all the times in the file to datetime objects
dt_time = [dt.date(1900, 1, 1) + dt.timedelta(hours=t) for t in time]

#convert to array
dt_time2 = np.array(dt_time)

date_index_array = np.where(dt_time2==set_date) #2589
date_index = np.squeeze(date_index_array)

# %%
# #create new netcdf files to check correlation between
# #if says permission denied, file already exists so skip

# #nc is full dataset
# #cropped_nc is full dataset just for region
# #nc_2 is cropped dataset for region and just for single day (e.g. heatwave)
# #still need to repeat for each time


# if os.path.exists(fn):
#     os.remove(fn)
# nc = xr.open_dataset("/nfs/annie/ee21pnm/daymean_present.nc")

# #slice data for lat longs
# mask_lon = (nc.longitude >= lon_min) & (nc.longitude <= lon_max)
# mask_lat = (nc.latitude >= lat_min) & (nc.latitude <= lat_max)
# cropped_nc = nc.where(mask_lon & mask_lat, drop=True)

# cropped_nc.to_netcdf(fn, 'w', format='NETCDF4')

# print('Complete!')
# Out:
# Complete!

# %%
# #create new netcdf files to check correlation between

    
# if os.path.exists(fn2):
#     os.remove(fn2)

# nc = xr.open_dataset("/nfs/annie/ee21pnm/daymean_present.nc")

# ##slice data for lat longs
# mask_lon = (nc.longitude >= lon_min) & (nc.longitude <= lon_max)
# mask_lat = (nc.latitude >= lat_min) & (nc.latitude <= lat_max)
# cropped_nc = nc.where(mask_lon & mask_lat, drop=True)

# ##slice data  for one day
# nc_2 = cropped_nc.isel(time=int(date_index))

# ##repeat same single day data for all times


# ##write new netcdf file

# ##create netcdf
# nc_2.to_netcdf(fn2, 'w', format='NETCDF4')

# print('Complete!')
# Out:
# Complete!

# %%
#load control day cube (eg 28 June 2021)
cube1 = iris.load_cube(fn2)

longitude = cube1.coord('longitude')
latitude = cube1.coord('latitude')

# Functions to identify latitudes and longitudes we want to subset to
#def region_lat(input):
#    return lat_min  <= input <= lat_max 

#def region_long(input):
#    return lon_min  <= input <= lon_max 

#region_con = iris.Constraint(latitude = region_lat, longitude = region_long)

# Subset the cube to the location of interest
#region_subset = cube1.extract(region_con)

#find spatial average for each day
coords = ('longitude', 'latitude')

#find cosine latitude weighting for varying area of earth grid
#cosinelat_weights=iris.analysis.cartography.cosine_latitude_weights(cube1)

#sort cube by increasing latitude
cube1_sorted = sorted(cube1, 'latitude')

# %%
#load all days
cube2 = iris.load_cube(fn)

longitude2 = cube2.coord('longitude')
latitude2 = cube2.coord('latitude')

coords2 = ('longitude', 'latitude')

#sort cube by increasing latitude
cube2_sorted = sorted(cube2, 'latitude')

# %%
#LOWRES resample cubes to make smaller and match lat/longs from model data
sample_points = [('longitude', longitude_lowRES.points),
                 ('latitude',  latitude_lowRES.points)]
resampled_cube1 = cube1_sorted.interpolate(sample_points, iris.analysis.Linear())
resampled_cube2 = cube2_sorted.interpolate(sample_points, iris.analysis.Linear())

cosinelat_weights=iris.analysis.cartography.cosine_latitude_weights(resampled_cube1)

# %%
#iris.analysis.cartography.area_weights(cube1) doesnt work as needs lat long bounds, so use cosine lat
#cube2[1]
#corr1 = iris.analysis.stats.pearsonr(cube1, cube2[2589], weights=iris.analysis.cartography.cosine_latitude_weights(cube1))

# %%
print(cube1)
print(resampled_cube1)
# Out:
# geopotential / (m**2 s**-2)         (latitude: 161; longitude: 301)
#      Dimension coordinates:
#           latitude                           x               -
#           longitude                          -               x
#      Attributes:
#           CDI: Climate Data Interface version 1.9.3 (http://mpimet.mpg.de/cdi)
#           CDO: Climate Data Operators version 1.9.3 (http://mpimet.mpg.de/cdo)
#           Conventions: CF-1.6
#           frequency: day
#           history: Thu Mar 24 14:59:01 2022: cdo -daymean /nfs/annie/ee21pnm/present.nc /nfs/annie/ee21pnm/daymean_present.nc
# 2022-03-23...
# geopotential / (m**2 s**-2)         (latitude: 58; longitude: 107)
#      Dimension coordinates:
#           latitude                           x              -
#           longitude                          -              x
#      Attributes:
#           CDI: Climate Data Interface version 1.9.3 (http://mpimet.mpg.de/cdi)
#           CDO: Climate Data Operators version 1.9.3 (http://mpimet.mpg.de/cdo)
#           Conventions: CF-1.6
#           frequency: day
#           history: Thu Mar 24 14:59:01 2022: cdo -daymean /nfs/annie/ee21pnm/present.nc /nfs/annie/ee21pnm/daymean_present.nc
# 2022-03-23...

# %%
#calculate correlation

corr = np.zeros(len(dt_time2))
for i in np.arange(len(dt_time2)):
    correlation = iris.analysis.stats.pearsonr(resampled_cube1, resampled_cube2[i], weights=cosinelat_weights)
    corr[i] = correlation.data

# %%
#load datasets to apply weighting for RMSE
unweighted_zHW = resampled_cube1.data

#model
unweighted_zPNW = resampled_cube2.data

zPNW = unweighted_zPNW * cosinelat_weights
zHW = unweighted_zHW * cosinelat_weights

#corr2= np.corrcoef(z[1],z[1])
print('Done!')
# Out:
# Done!

# %%
#Calculate RMSE and spatial corr

SCC = np.zeros(len(dt_time2))
RMSE = np.zeros(len(dt_time2))
for i in np.arange(len(dt_time2)):
    SCC[i] = scc(zHW,zPNW[i])
    RMSE[i] = rmse(zHW,zPNW[i])

# %%
corr_series = pd.DataFrame({'dates':dt_time2,'p_corr': corr,'SCC': SCC, 'RMSE': RMSE}, columns=['dates','p_corr','SCC', 'RMSE'])
corr_series
# Out:
#            dates    p_corr       SCC         RMSE
# 0     1979-06-01  0.756759  0.325097   806.250513
# 1     1979-06-02  0.796199  0.278738   922.729277
# 2     1979-06-03  0.797156  0.262241  1101.030188
# 3     1979-06-04  0.764489  0.207192  1186.530206
# 4     1979-06-05  0.693405  0.192733  1278.265741
# 5     1979-06-06  0.654044  0.137642  1254.015285
# 6     1979-06-07  0.687894  0.268064  1124.785841
# 7     1979-06-08  0.734668  0.231998   997.004501
# 8     1979-06-09  0.767961  0.165348   904.807931
# 9     1979-06-10  0.822537  0.199571   886.888291
# 10    1979-06-11  0.796077  0.144071   996.870447
# 11    1979-06-12  0.699293  0.135499  1091.566848
# 12    1979-06-13  0.616761  0.148460  1101.607320
# 13    1979-06-14  0.656905  0.153663  1046.828964
# 14    1979-06-15  0.698626  0.211663   967.400305
# 15    1979-06-16  0.737862  0.179475   971.134204
# 16    1979-06-17  0.756738  0.235169   970.014019
# 17    1979-06-18  0.751505  0.196452   940.580913
# 18    1979-06-19  0.726170  0.181626   872.948549
# 19    1979-06-20  0.717132  0.231841   831.389910
# 20    1979-06-21  0.725203  0.202708   808.335302
# 21    1979-06-22  0.721195  0.192244   771.416205
# 22    1979-06-23  0.746571  0.208296   768.917610
# 23    1979-06-24  0.720765  0.158516   820.396628
# 24    1979-06-25  0.724516  0.151096   767.053629
# 25    1979-06-26  0.812650  0.130717   664.566407
# 26    1979-06-27  0.850023  0.128915   677.872706
# 27    1979-06-28  0.818706  0.180152   684.322622
# 28    1979-06-29  0.737215  0.228132   742.578878
# 29    1979-06-30  0.567959  0.182998   853.362941
# ...          ...       ...       ...          ...
# 2593  2021-07-02  0.643079  0.192840   586.190484
# 2594  2021-07-03  0.650510  0.180165   612.523015
# 2595  2021-07-04  0.718530  0.174985   556.160529
# 2596  2021-07-05  0.823583  0.199793   440.437808
# 2597  2021-07-06  0.876941  0.200438   382.785161
# 2598  2021-07-07  0.862165  0.192064   473.788674
# 2599  2021-07-08  0.843683  0.272554   547.812330
# 2600  2021-07-09  0.825626  0.218031   517.117981
# 2601  2021-07-10  0.788682  0.199890   511.380323
# 2602  2021-07-11  0.743300  0.169700   529.068146
# 2603  2021-07-12  0.760425  0.168992   498.246520
# 2604  2021-07-13  0.830827  0.193822   440.080507
# 2605  2021-07-14  0.822210  0.244180   461.828246
# 2606  2021-07-15  0.754777  0.276350   566.086139
# 2607  2021-07-16  0.706147  0.151221   615.710856
# 2608  2021-07-17  0.663205  0.140396   596.605899
# 2609  2021-07-18  0.716036  0.149716   561.742735
# 2610  2021-07-19  0.732698  0.087615   543.057669
# 2611  2021-07-20  0.714398  0.220933   558.123135
# 2612  2021-07-21  0.672066  0.182457   617.299209
# 2613  2021-07-22  0.581927  0.207271   689.707093
# 2614  2021-07-23  0.627861  0.141168   691.373454
# 2615  2021-07-24  0.772393  0.248616   627.403718
# 2616  2021-07-25  0.822392  0.173977   658.367865
# 2617  2021-07-26  0.832353  0.174407   674.040431
# 2618  2021-07-27  0.801453  0.170275   650.887535
# 2619  2021-07-28  0.802036  0.207545   567.070012
# 2620  2021-07-29  0.808591  0.223725   518.638055
# 2621  2021-07-30  0.776784  0.221956   534.944057
# 2622  2021-07-31  0.784436  0.200836   508.875785
#
# [2623 rows x 4 columns]

# %%
corr_series.to_excel(output_name)

# %%
#Load from excel
#run top 2 cells

corr_series = pd.read_excel('Spreadsheets/PNW_Corr_2021_06_28.xlsx', index_col=0)  
corr_series
# Out:
#           dates    p_corr       SCC         RMSE
# 0    1979-06-01  0.728037  0.606428   910.855060
# 1    1979-06-02  0.750702  0.605491   963.932841
# 2    1979-06-03  0.689238  0.584875  1089.850093
# 3    1979-06-04  0.637597  0.568911  1219.547963
# 4    1979-06-05  0.542713  0.515872  1374.991425
# 5    1979-06-06  0.446066  0.490713  1398.154013
# 6    1979-06-07  0.500111  0.524034  1298.302864
# 7    1979-06-08  0.597480  0.555666  1175.115550
# 8    1979-06-09  0.626701  0.536665  1056.306833
# 9    1979-06-10  0.591967  0.549050   955.573685
# 10   1979-06-11  0.550920  0.533503   992.451304
# 11   1979-06-12  0.525569  0.484709  1121.766358
# 12   1979-06-13  0.468765  0.468290  1231.113101
# 13   1979-06-14  0.469218  0.468602  1248.975208
# 14   1979-06-15  0.490196  0.526372  1181.965342
# 15   1979-06-16  0.432211  0.541416  1148.346521
# 16   1979-06-17  0.447358  0.554963  1112.199886
# 17   1979-06-18  0.493647  0.518424  1081.205966
# 18   1979-06-19  0.535174  0.553288  1048.575983
# 19   1979-06-20  0.555806  0.572744   994.066087
# 20   1979-06-21  0.521933  0.559197   950.873489
# 21   1979-06-22  0.494620  0.569949   862.029363
# 22   1979-06-23  0.526372  0.547642   840.582343
# 23   1979-06-24  0.552643  0.511587   911.163949
# 24   1979-06-25  0.609933  0.528814   852.472916
# 25   1979-06-26  0.672758  0.521431   736.240869
# 26   1979-06-27  0.681589  0.550286   714.704612
# 27   1979-06-28  0.678901  0.545644   736.151873
# 28   1979-06-29  0.602690  0.534125   826.267471
# 29   1979-06-30  0.353208  0.509340   956.871417
# ...         ...       ...       ...          ...
# 2593 2021-07-02  0.611192  0.528515   436.888942
# 2594 2021-07-03  0.595869  0.525148   483.670725
# 2595 2021-07-04  0.564106  0.540175   510.239762
# 2596 2021-07-05  0.587032  0.550119   471.672439
# 2597 2021-07-06  0.680637  0.551394   434.848866
# 2598 2021-07-07  0.700060  0.568544   531.288675
# 2599 2021-07-08  0.686933  0.584440   622.446210
# 2600 2021-07-09  0.721202  0.583822   568.148656
# 2601 2021-07-10  0.716112  0.575204   564.293717
# 2602 2021-07-11  0.696103  0.523444   577.414759
# 2603 2021-07-12  0.726659  0.516203   531.307762
# 2604 2021-07-13  0.720306  0.579981   483.297219
# 2605 2021-07-14  0.715800  0.587978   550.013816
# 2606 2021-07-15  0.701351  0.526121   685.070442
# 2607 2021-07-16  0.625169  0.482283   738.043994
# 2608 2021-07-17  0.510568  0.509454   687.459740
# 2609 2021-07-18  0.488840  0.517146   630.379452
# 2610 2021-07-19  0.498185  0.514721   605.490377
# 2611 2021-07-20  0.463077  0.548648   613.752614
# 2612 2021-07-21  0.384607  0.546103   689.965278
# 2613 2021-07-22  0.423389  0.504119   783.053038
# 2614 2021-07-23  0.558780  0.493195   774.706203
# 2615 2021-07-24  0.682028  0.589292   680.491605
# 2616 2021-07-25  0.665202  0.563240   693.163332
# 2617 2021-07-26  0.676490  0.557191   735.343099
# 2618 2021-07-27  0.680911  0.562812   725.041546
# 2619 2021-07-28  0.725158  0.577578   583.650477
# 2620 2021-07-29  0.736030  0.582960   493.536461
# 2621 2021-07-30  0.731783  0.597637   440.724600
# 2622 2021-07-31  0.740957  0.592070   393.750356
#
# [2623 rows x 4 columns]

# %%
#boxplot
year='1985'
mon='06'
day='18' 


fig1 = plt.figure(figsize=(5,5))
ax1 = fig1.add_subplot(1,2,1)
ax2 = fig1.add_subplot(1,2,2)

sns.boxplot(y=corr_series["p_corr"],color = 'orange', width=0.2,ax=ax1)
ax1.set(ylabel='')
ax1.set_title('Pearson Correlation \n Coefficient')

sns.boxplot(y=corr_series["RMSE"], color = 'green', width=0.2, ax=ax2)
ax2.set(ylabel='')
ax2.set_title('Root Mean \n Squared Error')
ax2.yaxis.tick_right()
ax2.grid(False)

#plot dashed lines
value1 = corr_series[corr_series['dates']==dt.date(int(year),int(mon),int(day))]['p_corr']
v1 = value1.iloc[0]
ax1.axhline(v1, color='r', linestyle='dashed', linewidth=1)
ax1.grid(False)

value2 = corr_series[corr_series['dates']==dt.date(int(year),int(mon),int(day))]['RMSE']
v2 = value2.iloc[0]
ax2.axhline(v2, color='r', linestyle='dashed', linewidth=1)


plt.tight_layout()

plt.savefig(pathout+'/PNW_boxplot_'+str(mon)+'.'+str(day)+'.'+str(year)+'.png',format ='png', dpi=150, bbox_inches='tight')
plt.show()

# %%
#find value for p_corr in dataframe

#year='1979'
#mon='07'
#day='18' 

value = corr_series[corr_series['dates']==dt.date(int(year),int(mon),int(day))]['p_corr']
v2 = value.iloc[0]

#matplotlib
fig1 = plt.figure(figsize=(10,5))
ax1 = fig1.add_subplot(1,1,1)
n, bins,patches = ax1.hist(corr_series['p_corr'], bins=50,color= 'grey', alpha=0.2)


#label value
bar_value_to_label = v2
min_distance = float("inf")  # initialize min_distance with infinity
index_of_bar_to_label = 0
for i, rectangle in enumerate(patches):  # iterate over every bar
    tmp = abs(  # tmp = distance from middle of the bar to bar_value_to_label
        (rectangle.get_x() +
            (rectangle.get_width() * (1 / 2))) - bar_value_to_label)
    if tmp < min_distance:  # we are searching for the bar with x cordinate
                            # closest to bar_value_to_label
        min_distance = tmp
        index_of_bar_to_label = i
        
patches[index_of_bar_to_label].set_color('r')
patches[index_of_bar_to_label].set_alpha(1)

plt.axvline(v2, color='r', linestyle='dashed', linewidth=1)


plt.title('PNW Pearson Correlation', fontsize=12)
plt.xlabel('Pearson Correlation Coefficient', fontsize=10)
plt.ylabel('Frequency', fontsize=10)


#plt.savefig(pathout+'/PNW_pCorr_histogram'+str(mon)+'.'+str(day)+'.'+str(year)+'.png',format ='png', dpi=150, bbox_inches='tight')
plt.show()

# %%
#repeat for SCC
value = corr_series[corr_series['dates']==dt.date(int(year),int(mon),int(day))]['SCC']
v2 = value.iloc[0]

#matplotlib
fig1 = plt.figure(figsize=(10,5))
ax1 = fig1.add_subplot(1,1,1)
n, bins,patches = ax1.hist(corr_series['SCC'], bins=50,color= 'grey', alpha=0.2)


#label value
bar_value_to_label = v2
min_distance = float("inf")  # initialize min_distance with infinity
index_of_bar_to_label = 0
for i, rectangle in enumerate(patches):  # iterate over every bar
    tmp = abs(  # tmp = distance from middle of the bar to bar_value_to_label
        (rectangle.get_x() +
            (rectangle.get_width() * (1 / 2))) - bar_value_to_label)
    if tmp < min_distance:  # we are searching for the bar with x cordinate
                            # closest to bar_value_to_label
        min_distance = tmp
        index_of_bar_to_label = i
        
patches[index_of_bar_to_label].set_color('r')
patches[index_of_bar_to_label].set_alpha(1)

plt.axvline(v2, color='r', linestyle='dashed', linewidth=1)


plt.title('PNW Spatial Correlation', fontsize=12)
plt.xlabel('Spatial Correlation Coefficient', fontsize=10)
plt.ylabel('Frequency', fontsize=10)


#plt.savefig(pathout+'/PNW_SCC_histogram'+str(mon)+'.'+str(day)+'.'+str(year)+'.png',format ='png', dpi=150, bbox_inches='tight')
plt.show()

# %%
#repeat for RMSE
value = corr_series[corr_series['dates']==dt.date(int(year),int(mon),int(day))]['RMSE']
v2 = value.iloc[0]

#matplotlib
fig1 = plt.figure(figsize=(10,5))
ax1 = fig1.add_subplot(1,1,1)
n, bins,patches = ax1.hist(corr_series['RMSE'], bins=50,color= 'grey', alpha=0.2)


#label value
bar_value_to_label = v2
min_distance = float("inf")  # initialize min_distance with infinity
index_of_bar_to_label = 0
for i, rectangle in enumerate(patches):  # iterate over every bar
    tmp = abs(  # tmp = distance from middle of the bar to bar_value_to_label
        (rectangle.get_x() +
            (rectangle.get_width() * (1 / 2))) - bar_value_to_label)
    if tmp < min_distance:  # we are searching for the bar with x cordinate
                            # closest to bar_value_to_label
        min_distance = tmp
        index_of_bar_to_label = i
        
patches[index_of_bar_to_label].set_color('r')
patches[index_of_bar_to_label].set_alpha(1)

plt.axvline(v2, color='r', linestyle='dashed', linewidth=1)


plt.title('PNW RMSE', fontsize=12)
plt.xlabel('Root Mean Squared Error', fontsize=10)
plt.ylabel('Frequency', fontsize=10)


#plt.savefig(pathout+'/PNW_RMSE_histogram'+str(mon)+'.'+str(day)+'.'+str(year)+'.png',format ='png', dpi=150, bbox_inches='tight')
plt.show()
